# %% [markdown]
# ## 08. 클래스

# %% [markdown]
# ### 08-01. 클래스 개요와 사용법

# %% [markdown]
# - 변수, 함수를 묶어서 코드 작성 실행 문법
# - 객체지향 구현 : 실제세계를 모델링하여 개발하는 개발방법론
# - 사용법 (메서드:클래스에서 선언된 함수)
# - 클래스선언(코드작성) > 객체생성(메모리사용) > 메서드호출(코드실행)
# - 클래스선언(설계도작성) > 객체생성(제품생산) > 메서드호출(제품사용)
# - 클래스 식별자 컨벤션 : PascalCase
# - class, self, spacial_methods(`__init__()`)
# - 클래스는 사용자정의 데이터타입이다.

# %% [markdown]
# ### 08-02. 클래스의 사용

# %% [markdown]
# - 클래스선언 : 코드작성
# - 계좌 : Account : balance, deposit(), withdraw()

# %%
class Account:

    balance = 10000

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        self.balance -= amount

# %% [markdown]
# - 객체생성 : 메모리사용

# %%
account1 = Account()
account2 = Account()

# %%
account1.balance, account2.balance
# Out:
# (10000, 10000)

# %% [markdown]
# - 메서드호출 : 코드실행

# %%
account1.deposit(3000)
account2.withdraw(2000)

# %%
account1.balance, account2.balance
# Out:
# (13000, 8000)

# %% [markdown]
# - dir() : 객체에 저장되어 있는 변수, 함수 출력

# %%
dir(account1)[-3:], dir(account2)[-3:]
# Out:
# (['balance', 'deposit', 'withdraw'], ['balance', 'deposit', 'withdraw'])

# %% [markdown]
# ### 08-03. self 명령어의 의미

# %% [markdown]
# - self : 객체자신
# - Account.deposit(amount) : self.balance += amount
# - account1.deposit(3000) : self.balance += amount
#     - self == account1 :  account1.balance += 3000

# %% [markdown]
# - Account.withdraw(amount) : self.balance -= amount
# - account2.withdraw(2000) : self.balance -= amount
#     - self == account2 : account2.balance -= 2000

# %%
print(account1.balance)
account1.balance = 15000
account1.balance
# Out:
# 13000
# 15000

# %%
account1.balance += 3000
account1.balance
# Out:
# 18000

# %% [markdown]
# ### 08-04. 클래스를 사용하여 스타크래프트 마린 유닛 만드는 문제

# %% [markdown]
# - 클래스선언 : 코드작성
# - 스타크래프트 : Marine : health=40, ap=5, attack(target)

# %%
# CODE

# %% [markdown]
# - 객체생성 : 메모리사용 : m1, m2

# %%
# CODE

# %% [markdown]
# - 메서드호출 : 코드실행 : m1.attack(m2)

# %%
# CODE

# %% [markdown]
# ### 08-05. 생성자 스페셜 메서드의 사용

# %% [markdown]
# - spacial methods
#     - 앞뒤로 __가 붙은 메서드
#     - 특별한 기능을 하는 메서드
#     - 생성자 메서드 : `__init__()` : 객체를 생성할때 실행되는 메서드
#         - 객체에서 변수의 초기값 설정
#         - 변수가 선언되지 않아 다른 메서드를 실행할때 에러가 발생하는것을 방지

# %%
# 클래스선언 : 코드작성
class Account:
    # 객체에서 사용되는 변수의 초기값을 설정할때 사용
    def __init__(self, balance=10000):
        self.balance = balance
    def deposit(self, amount):
        self.balance += amount
    def withdraw(self, amount):
        self.balance -= amount

# %%
# 객체생성 : 메모리사용
account = Account()

# %%
# 메서드호출 : 코드실행
account.deposit(2000)
account.balance
# Out:
# 12000

# %% [markdown]
# ### 08-06. 다양한 스페셜 메서드의 사용

# %% [markdown]
# - spacial methods
# - `__add__()`  : + 연산자 정의
# - `__eq__()`   : == 연산자 정의
# - `__repr__()` : 객체의 속성 출력 정의
# - `__str__()`  : print() 함수의 출력 정의

# %%
# 데이터 타입에 따라서 수행되는 연산이 다르다
d1, d2, d3, d4 = 1, 2, '3', '4'
d1 + d2, d3 + d4
# Out:
# (3, '34')

# %%
# __add__() == +
dir(d1)[:2], dir(d3)[:2]
# Out:
# (['__abs__', '__add__'], ['__add__', '__class__'])

# %%
# d1.__add__(d2) == d1 + d2
# d1.__add__(d2) : 클래스 int : int 클래스에 정의되어 있는 __add__() 호출
# d3.__add__(d4) : 클래스 str : str 클래스에 정의되어 있는 __add__() 호출
d1.__add__(d2), d1 + d2, d3.__add__(d4), d3 + d4
# Out:
# (3, 3, '34', '34')

# %%
class Number:
    def __init__(self, data):
        self.data = data
    def __add__(self, obj): # + 연산자 정의
        return self.data - obj.data
    def __repr__(self): # 객체의 속성값 출력 : 개발용
        print('repr')
        return f'<Number data:{self.data}>'
    def __str__(self): # 객체의 데이터 출력 : print() 함수실행
        print('str')
        return str(self.data)

# %%
n1 = Number(10)
n2 = Number(4)

# %%
n1
# Out:
# repr
# <Number data:10>

# %%
print(n1)
# Out:
# str
# 10

# %%
n1.__add__(n2), n1 + n2
# Out:
# (6, 6)

# %% [markdown]
# ### 08-07. 클래스와 데이터 타입의 관계

# %% [markdown]
# - 클래스는 사용자정의 데이터타입이다.

# %%
# 클래스선언 : 코드작성
class Account:
    # 객체에서 사용되는 변수의 초기값을 설정할때 사용
    def __init__(self, balance=10000):
        self.balance = balance
    def deposit(self, amount):
        self.balance += amount
    def withdraw(self, amount):
        self.balance -= amount

# %% [markdown]
# - acc 객체의 클래스 : Account
# - acc 객체의 데이터타입 : Account
# - 클래스는 데이터타입이다.
# - Account 클래스는 우리가 직접 만듦 : 사용자정의
# - 클래스는 사용자정의 데이터타입이다.

# %%
acc = Account()
type(acc)
# Out:
# __main__.Account

# %%
# data 객체의 클래스는 : str
# data 객체의 데이터타입 : str
# str 클래스는 우리가 만들지 X
data = 'python'
type(data)
# Out:
# str

# %%
# acc 객체의 클래스(Account:balance, deposit, withdraw)
# data 객체의 클래스(str:lower, split, count, upper ...)
dir(acc)[-3:], dir(data)[-3:]
# Out:
# (['balance', 'deposit', 'withdraw'], ['translate', 'upper', 'zfill'])

# %%
# 객체는 데이터타입(클래스)에 따라서 사용가능한 변수, 메서드가 다르다.
data.upper()
# Out:
# 'PYTHON'

# %%
ls = [1, 2, 3]
# dir(ls)
help(ls.sort)
# Out:
# Help on built-in function sort:
#
# sort(*, key=None, reverse=False) method of builtins.list instance
#     Sort the list in ascending order and return None.
#
#     The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
#     order of two equal elements is maintained).
#
#     If a key function is given, apply it once to each list item and sort them,
#     ascending or descending, according to their function values.
#
#     The reverse flag can be set to sort in descending order.

# %% [markdown]
# ### 08-08. 클래스의 상속

# %% [markdown]
# - 클래스 상속
#     - 다른 클래스의 변수와 메서드를 가져와서 사용하는 방법
#     - 다중 상속 가능
#         - IPhone1 : call()
#         - IPhone2 : call(), sms()
#         - IPhone3 : call(), sms(), internet()

# %%
class IPhone1():
    def call(self):
        print('calling')

class IPhone2(IPhone1):
    def sms(self):
        print('send sms')

# 다중상속 : IPhone1 > IPhone2 > IPhone3 : IPhone3(IPhone2, IPhone1)
class IPhone3(IPhone2):
    def call(self): # 메서드 오버라이딩
        print('calling face')
    def internet(self):
        print('use internet')

# %% [markdown]
# ### 08-09. is a, has a 개념
# - 클래스를 설계할때 사용하는 개념
# - is a : A is a B : A는 B이다. : A와 B는 동일하다.
# - has a : A has a B : A는 B를 포함한다.

# %%
# User 클래스 : name, age 정보

# %%
# is a : 상속

# %%
class Info:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
class User(Info):
    def disp(self):
        print(self.name, self.age)

# %%
user = User('peter', 20)
user.disp()
# Out:
# peter 20

# %%
# has a : 객체 > 생성자(아규먼트, 파라미터 : 객체)

# %%
class Name:
    def __init__(self, name_str):
        self.name_str = name_str

class Age:
    def __init__(self, age_str):
        self.age_str = age_str

# %%
name = Name('peter')
age = Age(20)

# %%
name.name_str
# Out:
# 'peter'

# %%
class User:
    def __init__(self, name_obj, age_obj):
        self.name_obj = name_obj
        self.age_obj = age_obj
    def disp(self):
        print(self.name_obj.name_str, self.age_obj.age_str)

# %%
user = User(name, age)
user.disp()
# Out:
# peter 20

# %% [markdown]
# ### 08-10. 클래스를 사용하여 스타크래프트 메딕 유닛 만드는 문제

# %% [markdown]
# - 문제. 아래의 코드에서 아래의 조건을 추가하여 클래스의 코드를 수정 또는 추가하세요.
#     - 생성자 메서드 사용
#     - max_health 추가
#     - 체력이 0이하이면 공격해도 체력이 감소하지 않음

# %%
class Marine:

    health, ap = 40, 5

    def attack(self, target):
        target.health -= self.ap

# %%
# CODE

# %% [markdown]
# - 문제. 메딕 클래스를 생성하세요.
#     -  메딕 클래스 생성 : Medic : health=60, hp=6
#     - 체력이 최대 체력이면 치료해도 체력이 증가하지 않음

# %%
# CODE

# %% [markdown]
# ### 08-11. 클래스 메서드 종류
# - Instance Method
#     - self 사용
#     - 객체를 통해서 사용
# - Class Method
#     - cls 사용
#     - 클래스를 통해서 사용
# - Static Method
#     - 클래스 안에 있는 일반 함수

# %%
# 이자율이 적용된 계좌 클래스

# %%
class Account:

    interest = 0.01

    def __init__(self, balance=0):
        self.balance = balance

    def change_interest_instance(self, interest):
        self.interest = interest

    @classmethod
    def change_interest_class(cls, interest):
        cls.interest = interest

    @staticmethod
    def change_interest_static(interest, obj):
        obj.interest = interest

# %%
acc1 = Account(1000)
acc2 = Account(2000)
acc3 = Account(3000)

# %%
acc1.interest, acc2.interest, acc3.interest
# Out:
# (0.01, 0.01, 0.01)

# %%
# instance method
acc1.change_interest_instance(0.03)
acc2.change_interest_instance(0.03)

# %%
acc1.interest, acc2.interest, acc3.interest
# Out:
# (0.03, 0.03, 0.01)

# %%
# class method
Account.change_interest_class(0.04)

# %%
acc1.interest, acc2.interest, acc3.interest
# Out:
# (0.03, 0.03, 0.04)

# %%
# static method
Account.change_interest_static(0.05, acc2)

# %%
acc1.interest, acc2.interest, acc3.interest
# Out:
# (0.03, 0.05, 0.04)

# %% [markdown]
# ## CH 09. 모듈, 패키지

# %% [markdown]
# ### 09-01. 모듈의 개요 및 만들기

# %% [markdown]
# - 모듈 : 변수, 함수, 클래스를 파일로 묶어서 코드 작성 실행
# - 패키지 : 여러개의 모듈을 디렉토리로 구분해서 코드 작성 실행
# - import, as, from

# %%
# %%writefile pymodule.py
data = 'python'

def echo():
    print('py msg')

class Text:
    def __init__(self, data):
        self.data = data
# Out:
# Overwriting pymodule.py

# %%
# %ls | grep pymodule.py
# Out:
# pymodule.py

# %%
# 선언된 변수 초기화
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %% [markdown]
# ### 09-02. 모듈 명령어 사용법

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import pymodule

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# pymodule   module    <module 'pymodule' from '<...>ktop/python/pymodule.py'>

# %%
# %cat pymodule.py
# Out:
# data = 'python'
#
# def echo():
#     print('py msg')
#
# class Text:
#     def __init__(self, data):
#         self.data = data

# %%
print(pymodule.data)
pymodule.echo()
txt = pymodule.Text('python obj')
txt.data
# Out:
# python
# py msg
# 'python obj'

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# from pymodule import data, echo
from pymodule import *

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# Text       type        <class 'pymodule.Text'>
# data       str         python
# echo       function    <function echo at 0x10486da80>

# %%
print(data)
echo()
# Out:
# python
# py msg

# %%
import pymodule as pm

print(pm.data)
pm.echo()
# Out:
# python
# py msg
